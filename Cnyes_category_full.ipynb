# %% [markdown]
# <a href="https://colab.research.google.com/github/cheng1103/News-Crawler-Test/blob/main/Cnyes_category.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1><span style="font-size:20px"><strong>鉅亨網新聞主題爬蟲（精確版，用於Colab平台）</strong></span></h1>
#
# <p>可自訂主題新聞與日期區間爬取新聞內文，並可設定是否爬取頭條以外的新聞<br />
# <span style="color:#cc0000"><strong>輸出資料依序為：張貼時間(時間戳)、張貼時間、版別、標題、撰文者、內文、標籤、網址</strong></span></p>
#
# <p>支援的分類新聞目錄：</p>
#
# <p>1.台股 V<br />
# &nbsp; a.台灣政經 V<br />
# &nbsp; b.台股盤勢 V<br />
# &nbsp; c.台股盤勢 V<br />
# &nbsp; d.台股盤勢 V</p>
#
# <p>2.國際股 V<br />
# &nbsp; a.美股 V<br />
# &nbsp; b.美股雷達 V<br />
# &nbsp; c.歐亞股 V<br />
# &nbsp; d.國際政經 V</p>
#
# <p>3.陸港股 V</p>
#
# <p>4.外匯 V</p>
#
# <p>5.期貨 V</p>
#
# <p>6.房產 V</p>
#
# <p>7.基金 V</p>
#
# <p>8.區塊鏈 V</p>

# %% [markdown]
# # 新聞類別與查詢區間設定

# %%
#設定區域
#==============================================
#頭條設定 
# 1表示限定頭條； 0表示不限 
Headline = 1

#輸入類別
c = '台股'

#查詢區間
s_time = "2021-01-01 00:00:00" #開始日期 
e_time = "2021-01-07 00:00:00" #結束日期


#==============================================

data_URL = []

kind = {
  '台股':'tw_stock',
  '台灣政經':'tw_macro',
  '台股盤勢':'tw_quo',
  '專家觀點':'stock_report',
  '台股新聞':'tw_stock_news',

  '國際股':'wd_stock',
  '美股':'us_stock',
  '美股雷達':'us_stock_live',
  '歐亞股':'eu_asia_stock',
  '國際政經':'wd_macro',

  '陸港股':'cn_stock',
  '外匯':'forex',
  '期貨':'future',
  '房產':'cnyeshouse',
  '基金':'fund',
  '區塊鏈':'bc'

}

c = kind.get(c)


#頭條篩選
if Headline == 1 :
  CH = '&isCategoryHeadline=1'
else :
  CH = ''

# %% [markdown]
# # 安裝並載入套件

# %%
# !pip install fake_useragent
from fake_useragent import UserAgent
import requests
from bs4 import BeautifulSoup
from lxml import etree

import random
import time
import datetime
import json
import pandas as pd
#%reset -f
# Out:
# Requirement already satisfied: fake_useragent in /usr/local/lib/python3.7/dist-packages (0.1.11)

# %% [markdown]
# # 自定義程式：爬取鉅亨網新聞網址清單

# %%
def url_list(s_time,e_time):
  
  #==============================================
  #時間區間設定
  s_time = int(time.mktime(time.strptime(s_time, "%Y-%m-%d %H:%M:%S")))-28800 # 轉成時間戳
  e_time = int(time.mktime(time.strptime(e_time, "%Y-%m-%d %H:%M:%S")))-28800

  #==============================================
  p = 1
  l_page = 9
  data = pd.DataFrame()

  while p <= l_page :

    headers = UserAgent().random #隨機請求表頭
    
    url = 'https://api.cnyes.com/media/api/v1/newslist/category/'+c+'?startAt='+str(s_time)+'&endAt='+str(e_time)+CH+"&limit=30&page="+str(p)
    req = requests.get(url, headers={"User-Agent":headers})
    req = req.json()

    #最末頁之路徑
    if p == 1:
      l_page = req["items"]["last_page"] 

    req_data = req["items"]["data"]
    temp_data = pd.DataFrame.from_dict(req_data)
    
    #擷取資料
    publishAt = temp_data['publishAt']
    newsId = temp_data['newsId']
    title = temp_data['title']
    #isIndex = temp_data['isIndex'] 
    isCategoryHeadline = temp_data['isCategoryHeadline']
    #categoryId = temp_data['categoryId']
    
    temp_data = pd.concat([publishAt, newsId, title, isCategoryHeadline ], 1)
    data = pd.concat([data, temp_data])
    
    

    #休眠
    t = random.uniform(0.005, 0.25) #隨機數
    time.sleep(t) #暫停

    p = p+1

    if p%50 == 0:
      print(p/l_page*100)
      time.sleep(0.5)

    if p%200 == 0:
      data.drop_duplicates(subset='newsId', keep='first', inplace=True) #移除重複資料
      time.sleep(2)

  data.drop_duplicates(subset='newsId', keep='first', inplace=True) #移除重複資料
  return(data)

# %% [markdown]
# # 執行程式

# %%
data_URL = url_list(s_time,e_time)
data_URL = data_URL.sort_values(by='publishAt', ascending=True)
data_URL = data_URL.reset_index(drop=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:36: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only

# %% [markdown]
# # 檢視新聞網址資料

# %%
data_URL
# Out:
#       publishAt  ...  isCategoryHeadline
# 0    1609472787  ...                   1
# 1    1609472921  ...                   1
# 2    1609473015  ...                   1
# 3    1609473064  ...                   1
# 4    1609473391  ...                   1
# ..          ...  ...                 ...
# 291  1610022710  ...                   1
# 292  1610022762  ...                   1
# 293  1610026301  ...                   1
# 294  1610026379  ...                   1
# 295  1610026523  ...                   1
#
# [296 rows x 4 columns]

# %% [markdown]
# # 爬取新聞內文

# %%
data = pd.DataFrame()
l_page = len(data_URL)

for i in range(l_page):

  headers = UserAgent().random
  url = data_URL['newsId'][i]
  url = 'https://news.cnyes.com/news/id/'+str(url)

  req = requests.get(url, headers={"User-Agent":headers})
  req = req.content.decode()
  req = etree.HTML(req)

  catalog = req.xpath('//*[@id="content"]/div/div/div[2]/main/div[2]/div[1]/nav/a/span/span/text()')
  catalog = ",".join(catalog)

  title = req.xpath('//*[@id="content"]/div/div/div[2]/main/div[2]/h1/text()')
  title = "".join(title)

  reporter = req.xpath('//*[@id="content"]/div/div/div[2]/main/div[2]/div[2]/span/span/text()')
  reporter = "".join(reporter)


  d_time = req.xpath('//*[@id="content"]/div/div/div[2]/main/div[2]/div[2]/time/text()')
  d_time = "".join(d_time)

  content = req.xpath('//*[@id="content"]/div/div/div[2]/main/div[3]/article/section[1]/div[2]/div/p/text() | //*[@id="content"]/div/div/div[2]/main/div[3]/article/section[1]/div[2]/div/p/a/text()')
  content = "".join(content)

  tag = req.xpath('//*[@id="content"]/div/div/div[2]/main/div[3]/article/section[1]/nav/a/span/text()')
  tag = ",".join(tag)

  publishAt = data_URL['publishAt'][i]
  #publishAt = url_list['publishAt'](index)


  temp_data ={(publishAt ,d_time, catalog, title, reporter, content, tag, url)}
  temp_data = pd.DataFrame(temp_data)
  #temp_data.columns = ['time', 'publishAt', 'catalog', 'title', 'reporter', 'content', 'tag']
  data = data.append(temp_data)

  t = random.uniform(0.005, 0.1) #隨機數
  time.sleep(t) #暫停

  #列印出進度
  if i % 50 == 0:
    print(i/l_page*100)
    time.sleep(0.4)

  if i % 250 == 0:
    time.sleep(2)
# Out:
# 0.0
# 16.89189189189189
# 33.78378378378378
# 50.67567567567568
# 67.56756756756756
# 84.45945945945947

# %% [markdown]
# # 檢視新聞內文資料

# %%
data.columns = [ 'publishAt', 'time', 'catalog', 'title', 'reporter', 'content', 'tag', 'url']
data
# Out:
#      publishAt  ...                                     url
# 0   1609472787  ...  https://news.cnyes.com/news/id/4555666
# 0   1609472921  ...  https://news.cnyes.com/news/id/4555657
# 0   1609473015  ...  https://news.cnyes.com/news/id/4555641
# 0   1609473064  ...  https://news.cnyes.com/news/id/4555695
# 0   1609473391  ...  https://news.cnyes.com/news/id/4555707
# ..         ...  ...                                     ...
# 0   1610022710  ...  https://news.cnyes.com/news/id/4557413
# 0   1610022762  ...  https://news.cnyes.com/news/id/4557425
# 0   1610026301  ...  https://news.cnyes.com/news/id/4557412
# 0   1610026379  ...  https://news.cnyes.com/news/id/4557427
# 0   1610026523  ...  https://news.cnyes.com/news/id/4557431
#
# [296 rows x 8 columns]

# %% [markdown]
# # 連結Google Drive並匯出資料

# %%
from google.colab import drive
drive.mount('/content/drive')


#輸出檔案
data.to_csv('/content/drive/MyDrive/Colab Notebooks/sample.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
